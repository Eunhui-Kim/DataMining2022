# %%
# p.13 of Autograd
import torch
x = torch.tensor([1., 2.])
y = torch.tensor([4., 5.])
z = torch.tensor([7., 3.])
x.requires_grad
# Out:
# False

# %%
(x + y).requires_grad
# Out:
# False

# %%
z.requires_grad = True
print("{}, {}".format((x + z).requires_grad, z.dtype))
# Out:
# True, torch.float32

# %%
# p.13 of Autograd
# torch.autograd.grad
t = torch.tensor([1., 2., 4.]).requires_grad_()
u = torch.tensor([10., 20.]).requires_grad_()
a = t.pow(2).sum() + u.log().sum()
torch.autograd.grad(a, (t, u))
# Out:
# (tensor([2., 4., 8.]), tensor([0.1000, 0.0500]))

# %%
import torch
a, b = torch.rand((2,2)), torch.rand((2,2))
print("a: {}\n, b: {} \n".format(a, b))

var1 = torch.sum(torch.abs((a * b)), 1)
print("L1 Distance is : ", var1)

var2 = torch.norm(((a * b)), 1, -1)
print("Torch NORM L1 Distance is : ", var2)

var3 = torch.sum(((a * b)) ** 2, 1).sqrt()
print("L2 SDistance is : ", var3)

var4 = torch.norm(((a * b)), 2, -1)
print("Torch NORM L2 Distance is : ", var4)
# Out:
# a: tensor([[0.6816, 0.0939],
#         [0.3072, 0.3175]])
# , b: tensor([[0.6887, 0.0302],
#         [0.3534, 0.2138]])
#
# L1 Distance is :  tensor([0.4723, 0.1764])
# Torch NORM L1 Distance is :  tensor([0.4723, 0.1764])
# L2 SDistance is :  tensor([0.4695, 0.1280])
# Torch NORM L2 Distance is :  tensor([0.4695, 0.1280])

# %%
# p.16 of Autograd
# Tensor.backward()
x = torch.tensor([-3., 2., 5.]).requires_grad_()
u = x.pow(3).sum()
print(" x.grad:{}\n u.backward:{}\n x.grad:{}\n".format(x.grad, u.backward(), x.grad))
# Out:
#  x.grad:None
#  u.backward:None
#  x.grad:tensor([27., 12., 75.])

# %%
# p.18 of Autograd
# Autograd machinery
w1 = torch.rand(5, 5).requires_grad_()
w2 = torch.rand(5, 5).requires_grad_()
x = torch.empty(5).normal_()
print("w1:{} \n w2: {} \n x : {}\n".format(w1, w2, x))

x0 = x
x1 = w1 @ x0
x2 = x0 + w2 @ x1
x3 = w1 @ (x1 + x2)

q = x3.norm()

q.backward()

# %%
# p.19 of Autograd
# Autograd machinery
x = torch.tensor([1.0, -2.0, 3.0, -4.0]).requires_grad_()
a = x.abs()
s = a.sum()
s
# Out:
# tensor(10., grad_fn=<SumBackward0>)

# %%
s.grad_fn.next_functions
# Out:
# ((<AbsBackward at 0x7f2e4b6426d8>, 0),)

# %%
# p.21 of Autograd
# Autograd machinery
import torch

w1 = torch.rand(20, 10).requires_grad_()
b1 = torch.rand(20).requires_grad_()
w2 = torch.rand(5, 20).requires_grad_()
b2 = torch.rand(5).requires_grad_()
print('w1:{} \n, b1:{} \n, w2:{} \n, b2:{} \n'.format(w1, b1, w2, b2))

x = torch.rand(10)
h = torch.tanh(w1 @ x + b1)
y = torch.tanh(w2 @ h + b2)
print('x:{} \n, h:{} \n, y:{} \n'.format(x, h, y))

target = torch.rand(5)
loss = (y - target).pow(2).mean()
print('target: {}\n, loss: {}\n'.format( target, loss))
# Out:
# w1:tensor([[0.2057, 0.1120, 0.3829, 0.7853, 0.9681, 0.3197, 1.0000, 0.3131, 0.4090,
#          0.1618],
#         [0.0949, 0.1882, 0.5115, 0.9619, 0.6528, 0.8209, 0.6551, 0.8423, 0.4855,
#          0.0661],
#         [0.1498, 0.5130, 0.6390, 0.2275, 0.6803, 0.5407, 0.7196, 0.2352, 0.9339,
#          0.9674],
#         [0.5897, 0.1471, 0.0135, 0.5327, 0.1497, 0.4337, 0.7124, 0.3906, 0.3266,
#          0.9996],
#         [0.2840, 0.3949, 0.0254, 0.9276, 0.6352, 0.5418, 0.9800, 0.6053, 0.7550,
#          0.5121],
#         [0.2209, 0.2918, 0.1900, 0.5239, 0.7762, 0.8402, 0.2674, 0.5707, 0.1937,
#          0.0828],
#         [0.7663, 0.5325, 0.8117, 0.9017, 0.3651, 0.1186, 0.0074, 0.7106, 0.4857,
#          0.6552],
#         [0.9668, 0.7396, 0.2956, 0.0957, 0.9644, 0.4260, 0.1408, 0.2792, 0.6495,
#          0.6851],
#         [0.6365, 0.0928, 0.0324, 0.5978, 0.7010, 0.8284, 0.5317, 0.1794, 0.1734,
#          0.8856],
#         [0.0307, 0.9785, 0.6952, 0.8634, 0.9863, 0.8879, 0.2057, 0.6693, 0.7353,
#          0.5982],
#         [0.5887, 0.1015, 0.5132, 0.1712, 0.3358, 0.0964, 0.7813, 0.0010, 0.1243,
#          0.7902],
#         [0.1205, 0.9179, 0.2901, 0.7790, 0.0757, 0.4230, 0.3983, 0.9610, 0.1350,
#          0.2890],
#         [0.4275, 0.7077, 0.3433, 0.4735, 0.9384, 0.0403, 0.2562, 0.8388, 0.5822,
#          0.0495],
#         [0.1718, 0.6770, 0.9676, 0.5124, 0.1925, 0.2156, 0.9812, 0.4091, 0.5525,
#          0.1580],
#         [0.7993, 0.6117, 0.0026, 0.6224, 0.6085, 0.0984, 0.6410, 0.3547, 0.0494,
#          0.6470],
#         [0.4196, 0.2719, 0.8174, 0.8224, 0.7248, 0.0813, 0.0357, 0.0641, 0.1854,
#          0.2680],
#         [0.2062, 0.3725, 0.2985, 0.9363, 0.8521, 0.0869, 0.8109, 0.8760, 0.7356,
#          0.1558],
#         [0.3244, 0.7986, 0.5248, 0.7608, 0.9982, 0.4470, 0.6922, 0.4527, 0.6592,
#          0.8433],
#         [0.6300, 0.5373, 0.4054, 0.1908, 0.0032, 0.2162, 0.8071, 0.2085, 0.6265,
#          0.3429],
#         [0.0896, 0.3345, 0.0745, 0.0348, 0.9341, 0.8744, 0.4455, 0.1740, 0.6130,
#          0.2703]], requires_grad=True)
# , b1:tensor([0.5764, 0.2358, 0.5036, 0.4858, 0.2553, 0.3252, 0.1423, 0.4346, 0.6663,
#         0.9071, 0.4100, 0.9023, 0.2135, 0.2818, 0.3473, 0.4526, 0.7833, 0.3583,
#         0.4684, 0.9513], requires_grad=True)
# , w2:tensor([[0.5318, 0.8793, 0.7208, 0.6428, 0.7086, 0.3981, 0.7363, 0.4877, 0.7181,
#          0.7245, 0.5968, 0.1569, 0.7121, 0.5060, 0.2556, 0.6227, 0.6757, 0.1694,
#          0.2090, 0.2191],
#         [0.7753, 0.3801, 0.1041, 0.0210, 0.2283, 0.3760, 0.5283, 0.1204, 0.0486,
#          0.8801, 0.5337, 0.7130, 0.1920, 0.9481, 0.7238, 0.5776, 0.9978, 0.4289,
#          0.8307, 0.1415],
#         [0.8663, 0.9947, 0.5523, 0.0031, 0.4916, 0.5156, 0.6993, 0.3534, 0.1933,
#          0.3033, 0.8112, 0.3330, 0.6258, 0.2521, 0.7585, 0.6503, 0.6578, 0.0068,
#          0.5178, 0.2547],
#         [0.1794, 0.7342, 0.3481, 0.6173, 0.5939, 0.5399, 0.8361, 0.7893, 0.5972,
#          0.4508, 0.4994, 0.1673, 0.7761, 0.8283, 0.5124, 0.6922, 0.0992, 0.5724,
#          0.9400, 0.4013],
#         [0.0185, 0.5755, 0.7361, 0.7957, 0.0283, 0.8176, 0.9764, 0.6869, 0.4524,
#          0.3326, 0.7832, 0.4502, 0.6618, 0.8978, 0.5205, 0.6110, 0.9544, 0.7357,
#          0.3622, 0.3271]], requires_grad=True)
# , b2:tensor([0.4620, 0.3639, 0.1427, 0.8494, 0.7282], requires_grad=True)
#
# x:tensor([0.1030, 0.2271, 0.9864, 0.7637, 0.8329, 0.8967, 0.1231, 0.4194, 0.7128,
#         0.9334])
# , h:tensor([0.9977, 0.9986, 0.9996, 0.9943, 0.9982, 0.9938, 0.9982, 0.9981, 0.9987,
#         1.0000, 0.9843, 0.9971, 0.9923, 0.9949, 0.9868, 0.9958, 0.9990, 0.9997,
#         0.9820, 0.9982], grad_fn=<TanhBackward>)
# , y:tensor([1., 1., 1., 1., 1.], grad_fn=<TanhBackward>)
#
# target: tensor([0.2039, 0.1414, 0.8583, 0.4763, 0.0191])
# , loss: 0.5254689455032349

# %%
# p.22 of Autograd
# Autograd machinery
w = torch.rand(3, 10, 10).requires_grad_()

def blah(k, x):
    for i in range(k):
        x = torch.tanh(w[i] @ x)
    return x

u = blah(1, torch.rand(10))
v = blah(3, torch.rand(10))
q = u.dot(v)
print('w: {} \n, u: {}\n, v: {}\n q: {}\n'.format(w, u, v, q))
# Out:
# w: tensor([[[0.8994, 0.2440, 0.1893, 0.6459, 0.5700, 0.9211, 0.2514, 0.0936,
#           0.8225, 0.7140],
#          [0.8251, 0.1572, 0.7071, 0.7246, 0.2332, 0.0252, 0.2717, 0.0095,
#           0.3958, 0.8589],
#          [0.4904, 0.7347, 0.5937, 0.8359, 0.7633, 0.9184, 0.0709, 0.2813,
#           0.5969, 0.7658],
#          [0.6238, 0.0499, 0.4602, 0.6955, 0.6587, 0.1786, 0.1717, 0.7216,
#           0.9971, 0.2023],
#          [0.5692, 0.5649, 0.7300, 0.8058, 0.1973, 0.5834, 0.1757, 0.3933,
#           0.4887, 0.3248],
#          [0.0969, 0.8534, 0.4092, 0.8902, 0.9609, 0.9601, 0.9526, 0.7646,
#           0.8020, 0.5499],
#          [0.3618, 0.0921, 0.0340, 0.7063, 0.2187, 0.2825, 0.7958, 0.3152,
#           0.9216, 0.3837],
#          [0.4946, 0.7579, 0.3342, 0.9217, 0.0402, 0.6776, 0.2853, 0.9225,
#           0.1210, 0.4640],
#          [0.3000, 0.4113, 0.0441, 0.6075, 0.0927, 0.7793, 0.3247, 0.4525,
#           0.3716, 0.6748],
#          [0.2985, 0.2954, 0.4066, 0.6649, 0.3951, 0.7282, 0.2323, 0.9887,
#           0.0694, 0.2903]],
#
#         [[0.2098, 0.7956, 0.9236, 0.2853, 0.9596, 0.8369, 0.7145, 0.4789,
#           0.8405, 0.1627],
#          [0.3435, 0.6750, 0.2713, 0.7815, 0.6210, 0.6499, 0.9498, 0.4791,
#           0.3625, 0.7149],
#          [0.0616, 0.8320, 0.0287, 0.8713, 0.3490, 0.9648, 0.9689, 0.2433,
#           0.6126, 0.1863],
#          [0.6262, 0.2098, 0.4264, 0.2480, 0.9363, 0.6819, 0.9908, 0.6165,
#           0.1997, 0.6009],
#          [0.7436, 0.3985, 0.5944, 0.7788, 0.6544, 0.3936, 0.8820, 0.4149,
#           0.0564, 0.0479],
#          [0.2484, 0.3359, 0.9277, 0.3900, 0.6400, 0.6189, 0.4615, 0.5359,
#           0.2655, 0.4983],
#          [0.3560, 0.6617, 0.3923, 0.5941, 0.1691, 0.6700, 0.5673, 0.2500,
#           0.0659, 0.7479],
#          [0.3655, 0.7823, 0.8611, 0.3027, 0.4852, 0.8809, 0.3522, 0.9071,
#           0.4141, 0.0561],
#          [0.9798, 0.9522, 0.4177, 0.2030, 0.1514, 0.8800, 0.6968, 0.9040,
#           0.7113, 0.7846],
#          [0.4681, 0.2197, 0.0389, 0.9988, 0.6030, 0.6145, 0.6686, 0.6355,
#           0.2869, 0.7264]],
#
#         [[0.5994, 0.1359, 0.3027, 0.7808, 0.3915, 0.5085, 0.2973, 0.0598,
#           0.6143, 0.2516],
#          [0.0437, 0.0229, 0.4397, 0.2581, 0.6577, 0.5936, 0.0088, 0.1974,
#           0.3973, 0.0348],
#          [0.2002, 0.1707, 0.4111, 0.2889, 0.0848, 0.3675, 0.9775, 0.0643,
#           0.1653, 0.9313],
#          [0.5590, 0.0978, 0.1232, 0.3657, 0.0065, 0.8465, 0.3825, 0.6750,
#           0.9268, 0.0011],
#          [0.4465, 0.6336, 0.6072, 0.4945, 0.0142, 0.8123, 0.1637, 0.6572,
#           0.8748, 0.8883],
#          [0.8210, 0.0863, 0.0950, 0.6002, 0.0336, 0.9673, 0.7722, 0.4769,
#           0.3379, 0.0493],
#          [0.8623, 0.5198, 0.0102, 0.4576, 0.8745, 0.0854, 0.0076, 0.1155,
#           0.2784, 0.3495],
#          [0.1123, 0.1647, 0.1178, 0.2694, 0.2172, 0.9288, 0.4181, 0.2679,
#           0.1999, 0.7620],
#          [0.3015, 0.9423, 0.2179, 0.9693, 0.8632, 0.1648, 0.0918, 0.3364,
#           0.2587, 0.4082],
#          [0.0781, 0.2268, 0.9625, 0.2090, 0.1006, 0.8243, 0.3884, 0.6008,
#           0.4519, 0.5708]]], requires_grad=True)
# , u: tensor([0.9908, 0.9720, 0.9913, 0.9791, 0.9736, 0.9971, 0.9744, 0.9856, 0.9740,
#         0.9586], grad_fn=<TanhBackward>)
# , v: tensor([0.9992, 0.9901, 0.9987, 0.9993, 1.0000, 0.9996, 0.9984, 0.9980, 0.9998,
#         0.9997], grad_fn=<TanhBackward>)
#  q: 9.77969741821289

# %%
a = torch.tensor([1, 3])
b = torch.tensor([2, 2])
c = a.dot(b)
c
# Out:
# tensor(8)

# %%
t = torch.tensor([1., 2., 4.]).requires_grad_()
u = torch.tensor([10., 20.]).requires_grad_()
a = t.pow(2).sum() + u.log().sum()
r = torch.autograd.grad(a, (t, u))
print("t:{} \n u:{} \n a:{} \n r = {} \n".format(t, u, a, r))
# Out:
# t:tensor([1., 2., 4.], requires_grad=True)
#  u:tensor([10., 20.], requires_grad=True)
#  a:26.298316955566406
#  r = (tensor([2., 4., 8.]), tensor([0.1000, 0.0500]))

# %%
s = u.log().sum()
torch.autograd.grad(s, u)
# Out:
# (tensor([0.1000, 0.0500]),)

# %%
w = torch.rand(3, 10).requires_grad_()
x = torch.rand(10)
y = w @ x
print('w: {},\n x: {},\n y: {}'.format(w, x, y))
# Out:
# w: tensor([[0.3344, 0.1228, 0.1076, 0.0149, 0.5912, 0.4252, 0.1110, 0.9417, 0.8678,
#          0.3534],
#         [0.0811, 0.6673, 0.7601, 0.3127, 0.8452, 0.5921, 0.6898, 0.9130, 0.8685,
#          0.5041],
#         [0.7137, 0.7244, 0.7692, 0.6394, 0.4351, 0.3559, 0.5943, 0.6452, 0.5802,
#          0.6465]], requires_grad=True),
#  x: tensor([0.4765, 0.6922, 0.3652, 0.6364, 0.8267, 0.9203, 0.4900, 0.7421, 0.6845,
#         0.9633]),
#  y: tensor([2.8608, 4.3164, 4.0066], grad_fn=<MvBackward>)

# %%
x = torch.tensor([1., 2., 2.]).requires_grad_()
q = x.norm()
q
# Out:
# tensor(3., grad_fn=<CopyBackwards>)

# %%
# p.24 of Autograd
# no_grad, detach
x = torch.rand(784)
w = torch.empty(10, 784).normal_(0, 1e-3).requires_grad_()
b = torch.empty(10).normal_(0, 1e-3).requires_grad_()
y = torch.rand(10)
eta = 0.01

for k in range(10001):
    y_hat = x @ w.t() + b
    loss = (y_hat - y).pow(2).mean()

    w.grad, b.grad = None, None
    loss.backward()

    with torch.no_grad():
        w -= eta * w.grad
        b -= eta * b.grad

# %%
# p.26 of Autograd
# no_grad, detach
a = torch.tensor( 0.5).requires_grad_()
b = torch.tensor(-0.5).requires_grad_()
for k in range(100):
    l = (a - 1)**2 + (b + 1)**2 + (a - b)**2
    ga, gb = torch.autograd.grad(l, (a, b))
    with torch.no_grad():
        a -= eta * ga
        b -= eta * gb
print('%.06f' % a.item(), '%.06f' % b.item())
# Out:
# 0.333676 -0.333676

# %%
# p.27 of Autograd
# no_grad, detach
a = torch.tensor( 0.5).requires_grad_()
b = torch.tensor(-0.5).requires_grad_()
for k in range(100):
    l = (a - 1)**2 + (b + 1)**2 + (a.detach() - b)**2
    ga, gb = torch.autograd.grad(l, (a, b))
    with torch.no_grad():
        a -= eta * ga
        b -= eta * gb
print('%.06f' % a.item(), '%.06f' % b.item())
# Out:
# 0.933690 -0.066310

# %%
# p.28 of Autograd
# create_graph = True
x = torch.tensor([1., 2., 3.]).requires_grad_()
phi = x.pow(2).sum()
g1, = torch.autograd.grad(phi, x, create_graph = True)
g1
# Out:
# tensor([2., 4., 6.], grad_fn=<MulBackward0>)

# %%
# p.28 of Autograd
# create_graph = True
psi = g1[0].exp() - g1[2].exp()
g2, = torch.autograd.grad(psi, x)
g2
# Out:
# tensor([  14.7781,    0.0000, -806.8576])

# %%
# p.29 of Autograd
x = torch.tensor([1., 2., 3.]).requires_grad_()
y = x.sin()
print('y : {}'.format(y))
l = y.sum()
l.backward()
print('l=sum(x.sin()), l : {}'.format(l))
y = x.sin()
y += 1
print('y : {}'.format(y))
l = y.sum()
l.backward()
print('l=sum(x.sin()+1), l : {}'.format(l))
y = x.sin()
y *=y
print('y : {}'.format(y))
l = y.sum()
print('l=sum(x.sin()*x.sin()), l : {}'.format(l))
l.backward()
print('l : {}'.format(l))
# Out:
# y : tensor([0.8415, 0.9093, 0.1411], grad_fn=<SinBackward>)
# l=sum(x.sin()), l : 1.8918883800506592
# y : tensor([1.8415, 1.9093, 1.1411], grad_fn=<AddBackward0>)
# l=sum(x.sin()+1), l : 4.891888618469238
# y : tensor([0.7081, 0.8268, 0.0199], grad_fn=<MulBackward0>)
# l=sum(x.sin()*x.sin()), l : 1.5548100471496582
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-51-e872d1ebe373> in <module>()
#      17 l = y.sum()
#      18 print('l=sum(x.sin()*x.sin()), l : {}'.format(l))
# ---> 19 l.backward()
#      20 print('l : {}'.format(l))
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
# --> 132         allow_unreachable=True)  # allow_unreachable flag
#     133
#     134
#
# RuntimeError: one of the variables needed for gradient computation has been modified by an inplace operation: [torch.FloatTensor [3]], which is output 0 of SinBackward, is at version 1; expected version 0 instead. Hint: enable anomaly detection to find the operation that failed to compute its gradient, with torch.autograd.set_detect_anomaly(True).
